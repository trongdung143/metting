# %%
import requests

url = "https://2dc6-34-125-133-130.ngrok-free.app/stt"

with open("test.wav", "rb") as f:
    r = requests.post(
        url,
        data=f.read(),
        headers={"Content-Type": "application/octet-stream"}
    )

data = r.json()

# %%
data[0]
# Out:
# {'segments': [{'text': ' Alo alo, có gì vui không? Kể tôi nghe với bạn là cái đồ quần què đúng không?',
#    'start': 0.031,
#    'end': 4.334}],
#  'language': 'vi'}

# %%
data[1]
# Out:
# {'segments': [{'start': 0.031,
#    'end': 0.9,
#    'text': ' Alo alo, có gì vui không?',
#    'words': [{'word': 'Alo', 'start': 0.031, 'end': 0.112, 'score': 0.014},
#     {'word': 'alo,', 'start': 0.132, 'end': 0.213, 'score': 0.015},
#     {'word': 'có', 'start': 0.233, 'end': 0.273, 'score': 0.014},
#     {'word': 'gì', 'start': 0.334, 'end': 0.395, 'score': 0.01},
#     {'word': 'vui', 'start': 0.415, 'end': 0.475, 'score': 0.01},
#     {'word': 'không?', 'start': 0.496, 'end': 0.9, 'score': 0.012}]},
#   {'start': 0.92,
#    'end': 4.354,
#    'text': 'Kể tôi nghe với bạn là cái đồ quần què đúng không?',
#    'words': [{'word': 'Kể', 'start': 0.92, 'end': 0.96, 'score': 0.01},
#     {'word': 'tôi', 'start': 0.98, 'end': 1.041, 'score': 0.013},
#     {'word': 'nghe', 'start': 1.324, 'end': 1.607, 'score': 0.012},
#     {'word': 'với', 'start': 1.667, 'end': 1.89, 'score': 0.014},
#     {'word': 'bạn', 'start': 1.91, 'end': 1.991, 'score': 0.012},
#     {'word': 'là', 'start': 2.011, 'end': 2.294, 'score': 0.013},
#     {'word': 'cái', 'start': 2.334, 'end': 2.536, 'score': 0.014},
#     {'word': 'đồ', 'start': 2.556, 'end': 2.597, 'score': 0.012},
#     {'word': 'quần', 'start': 2.94, 'end': 3.182, 'score': 0.016},
#     {'word': 'què', 'start': 3.263, 'end': 3.425, 'score': 0.014},
#     {'word': 'đúng', 'start': 3.445, 'end': 3.546, 'score': 0.008},
#     {'word': 'không?', 'start': 3.647, 'end': 4.354, 'score': 0.014}]}],
#  'word_segments': [{'word': 'Alo',
#    'start': 0.031,
#    'end': 0.112,
#    'score': 0.014},
#   {'word': 'alo,', 'start': 0.132, 'end': 0.213, 'score': 0.015},
#   {'word': 'có', 'start': 0.233, 'end': 0.273, 'score': 0.014},
#   {'word': 'gì', 'start': 0.334, 'end': 0.395, 'score': 0.01},
#   {'word': 'vui', 'start': 0.415, 'end': 0.475, 'score': 0.01},
#   {'word': 'không?', 'start': 0.496, 'end': 0.9, 'score': 0.012},
#   {'word': 'Kể', 'start': 0.92, 'end': 0.96, 'score': 0.01},
#   {'word': 'tôi', 'start': 0.98, 'end': 1.041, 'score': 0.013},
#   {'word': 'nghe', 'start': 1.324, 'end': 1.607, 'score': 0.012},
#   {'word': 'với', 'start': 1.667, 'end': 1.89, 'score': 0.014},
#   {'word': 'bạn', 'start': 1.91, 'end': 1.991, 'score': 0.012},
#   {'word': 'là', 'start': 2.011, 'end': 2.294, 'score': 0.013},
#   {'word': 'cái', 'start': 2.334, 'end': 2.536, 'score': 0.014},
#   {'word': 'đồ', 'start': 2.556, 'end': 2.597, 'score': 0.012},
#   {'word': 'quần', 'start': 2.94, 'end': 3.182, 'score': 0.016},
#   {'word': 'què', 'start': 3.263, 'end': 3.425, 'score': 0.014},
#   {'word': 'đúng', 'start': 3.445, 'end': 3.546, 'score': 0.008},
#   {'word': 'không?', 'start': 3.647, 'end': 4.354, 'score': 0.014}]}

# %%
data[2]
# Out:
# {'segments': [{'start': 0.031,
#    'end': 0.9,
#    'text': ' Alo alo, có gì vui không?',
#    'words': [{'word': 'Alo',
#      'start': 0.031,
#      'end': 0.112,
#      'score': 0.014,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'alo,',
#      'start': 0.132,
#      'end': 0.213,
#      'score': 0.015,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'có',
#      'start': 0.233,
#      'end': 0.273,
#      'score': 0.014,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'gì',
#      'start': 0.334,
#      'end': 0.395,
#      'score': 0.01,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'vui',
#      'start': 0.415,
#      'end': 0.475,
#      'score': 0.01,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'không?',
#      'start': 0.496,
#      'end': 0.9,
#      'score': 0.012,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 0.92,
#    'end': 4.354,
#    'text': 'Kể tôi nghe với bạn là cái đồ quần què đúng không?',
#    'words': [{'word': 'Kể',
#      'start': 0.92,
#      'end': 0.96,
#      'score': 0.01,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'tôi',
#      'start': 0.98,
#      'end': 1.041,
#      'score': 0.013,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'nghe',
#      'start': 1.324,
#      'end': 1.607,
#      'score': 0.012,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'với',
#      'start': 1.667,
#      'end': 1.89,
#      'score': 0.014,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'bạn',
#      'start': 1.91,
#      'end': 1.991,
#      'score': 0.012,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'là',
#      'start': 2.011,
#      'end': 2.294,
#      'score': 0.013,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'cái',
#      'start': 2.334,
#      'end': 2.536,
#      'score': 0.014,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'đồ',
#      'start': 2.556,
#      'end': 2.597,
#      'score': 0.012,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'quần',
#      'start': 2.94,
#      'end': 3.182,
#      'score': 0.016,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'què',
#      'start': 3.263,
#      'end': 3.425,
#      'score': 0.014,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'đúng',
#      'start': 3.445,
#      'end': 3.546,
#      'score': 0.008,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'không?',
#      'start': 3.647,
#      'end': 4.354,
#      'score': 0.014,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'}],
#  'word_segments': [{'word': 'Alo',
#    'start': 0.031,
#    'end': 0.112,
#    'score': 0.014,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'alo,',
#    'start': 0.132,
#    'end': 0.213,
#    'score': 0.015,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'có',
#    'start': 0.233,
#    'end': 0.273,
#    'score': 0.014,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'gì',
#    'start': 0.334,
#    'end': 0.395,
#    'score': 0.01,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'vui',
#    'start': 0.415,
#    'end': 0.475,
#    'score': 0.01,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'không?',
#    'start': 0.496,
#    'end': 0.9,
#    'score': 0.012,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'Kể',
#    'start': 0.92,
#    'end': 0.96,
#    'score': 0.01,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'tôi',
#    'start': 0.98,
#    'end': 1.041,
#    'score': 0.013,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'nghe',
#    'start': 1.324,
#    'end': 1.607,
#    'score': 0.012,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'với',
#    'start': 1.667,
#    'end': 1.89,
#    'score': 0.014,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'bạn',
#    'start': 1.91,
#    'end': 1.991,
#    'score': 0.012,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'là',
#    'start': 2.011,
#    'end': 2.294,
#    'score': 0.013,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'cái',
#    'start': 2.334,
#    'end': 2.536,
#    'score': 0.014,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'đồ',
#    'start': 2.556,
#    'end': 2.597,
#    'score': 0.012,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'quần',
#    'start': 2.94,
#    'end': 3.182,
#    'score': 0.016,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'què',
#    'start': 3.263,
#    'end': 3.425,
#    'score': 0.014,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'đúng',
#    'start': 3.445,
#    'end': 3.546,
#    'score': 0.008,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'không?',
#    'start': 3.647,
#    'end': 4.354,
#    'score': 0.014,
#    'speaker': 'SPEAKER_00'}]}

# %%
import requests

url = "http://localhost:8080/transcribe"

payload = {"audio_path": "src/test/data/test.wav"}

response = requests.post(url, params=payload)

print("Status code:", response.status_code)
print("Response JSON:")
print(response.json())
# Out:
# Status code: 200
# Response JSON:
# [{'start': 0.031, 'end': 0.9, 'text': 'Alo alo, có gì vui không?', 'speaker': 'SPEAKER_00'}, {'start': 0.92, 'end': 4.354, 'text': 'Kể tôi nghe với bạn là cái đồ quần què đúng không?', 'speaker': 'SPEAKER_00'}]
